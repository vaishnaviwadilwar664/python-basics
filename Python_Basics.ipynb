# %% [markdown]
# 1. What is Python, and why is it popular?
#       - Python is a high level interpreted language.
#       - Python was created by Guido van rossum in 1991 while watching the movie monty python.
#       - It is popular for its simplicity,versatability, readabilityand ease of learning.
#       - This is widely used in data industry.
#       - It has lots of libraries and has huge active community.
#       - It is used for the automation, image processing, etc.
#
# 2. What is an interpreter in Python?
#       - In python Interpreter is the program that translate your code into machine understandable language.
#       - Interpreter execute the code step by step.
#       - The debugging in the python is easy because it execute code step by step.
#
# 3. What are pre-defined keywords in Python?
#       - Pre-defined keywords are the reserved words which has the special meaning in the Python.
#       - this keywords are cannot be used as the identifier/variable name/ function name.
#       - keywords are case sensitive.
#       - Pre-defined keywords example are, if,while,for,def,try,break,continue,false,true,etc.
#
# 4. Can keywords be used as variable names?
#       - No, Keywords are cannot be used as the variable name.
#
# 5. What is mutability in Python?
#       - Mutability means the changing,updating the values/elements of the object.
#
#
# 6. Why are lists mutable, but tuples are immutable?
#       - Lists stores and also manage, update,change the elements of object, so they are mutable.
#       - Tuples are only stores the elements means once the object is stored we cannot change their elements,so they are immutable.
#
# 7. What is the difference between “==” and “is” operators in Python?
#       - In python "==" operator is called the assignment operator(double equal to). This is used to compare the values of the objets.
#       - ex.
#             a=[1,2,3]
#             b=[1,2,3]
#             c=a
#             print(a==b)          //True
#             print(a==c)          //True
#       - "is" operator is the identity operator this is used to compare the identity of objects.
#       - ex.
#             a=[1,2,3]
#             b=[1,2,3]
#             c=a
#             print(a is b)        //False
#             print(a is c)        //True
#
# 8. What are logical operators in Python?
#       - Logical operators are the operators which are used to combine conditional statements.
#       - following are the logical operators in python-
#             Logical AND              //and
#             Logical OR               //or
#             Logical NOT              //not
#
# 9. What is type casting in Python?
#       - In python type casting is the changing the data type to another data type.
#       - This is also known as type conversion.
#       - Python uses the build in functions for type casting like int(),float(),str(),etc.
#
# 10. What is the difference between implicit and explicit type casting?
#       - implicit type casting is done by the computer because python understands the type automatically.
#       - explicit type casting means we have to give the command explicitly for changing type.
#
# 11. What is the purpose of conditional statements in Python?
#       - In python conditional statements are used to make decisions based on certain conditions.
#       - following are the conditional statements -
#              if
#              if-else
#              if-elif-else
#              nested if-else
#
# 12. How does the elif statement work?
#       - syntax of elif statement-
#              elif condition true:
#                     block of code
#
#       - elif statement is came when the if statement is not getting fulfill.
#       - when the elif statement condition is true then the block of elif statement will run.
#
# 13. What is the difference between for and while loops?
#       - for loop are used for iterating over a sequence of elements.
#       - while loop are execute repeatadely in a loop while the certain condition is not met.
#
# 14. Describe a scenario where a while loop is more suitable than a for loop.
#       - while loop is used when the number of iteration is not known in advance like password verification.
#       - for loop is used when the iteration numbers are known in advance like printing the some pattern.

# %%
# 1. Write a Python program to print "Hello, World!"

print("Hello, World!")

# 2. Write a Python program that displays your name and age.

print("Name : Vaishnavi Ashok Wadilwar")
print("Age is: 20")

# 3. Write code to print all the pre-defined keywords in Python using the keyword library.

help("keywords")

# 4. Write a program that checks if a given word is a Python keyword.

import keyword
word = input("Enter a word to check: ")
if keyword.iskeyword(word):
    print(f"'{word}' is a Python keyword.")
else:
    print(f"'{word}' is NOT a Python keyword.")


# 5. Create a list and tuple in Python, and demonstrate how attempting to change an element works differently for each.

my_list = [10, 20, 30]
my_tuple = (10, 20, 30)

my_list[1] = 200
print("Modified list:", my_list)
try:
    my_tuple[1] = 200
except TypeError as e:
    print("Error when modifying tuple:", e)


# 6. Write a function to demonstrate the behavior of mutable and immutable arguments.

def modify_args(num, nums_list):
    num += 10
    nums_list.append(99)

x = 5

my_list = [1, 2, 3]

modify_args(x, my_list)

print("After function call:")
print("Integer (immutable):", x)
print("List (mutable):", my_list)


# 7. Write a program that performs basic arithmetic operations on two user-input numbers.

a=int(input("Enter First number: "))
b=int(input("Enter Second number: "))
print("Addition is: ",a+b)
print("subtraction is: ",a-b)
print("divide is: ",a/b)
print("multiplication is: ",a*b)
print("modulo is: ",a%b)
print("exponential is: ",a**b)

# 8. Write a program to demonstrate the use of logical operators.

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a > 0 and b > 0:
    print("Both numbers are positive.")

if a > 0 or b > 0:
    print("At least one number is positive.")

if not (a < 0 and b < 0):
    print("It is NOT true that both numbers are negative.")
else:
    print("Both numbers are negative.")


# 9. Write a Python program to convert user input from string to integer, float, and boolean types.

n=input("Enter the string")
try:
    num = int(n)
    print(num)
except ValueError:
    print("Invalid input: cannot convert to integer")
try:
    num = float(n)
    print(num)
except ValueError:
    print("Invalid input: cannot convert to float")
bool_value = bool(n)
print("Boolean value:", bool_value)

# 10. Write code to demonstrate type casting with list elements.

str_list = ['10', '20', '30', '40']
int_list = []
for item in str_list:
    int_list.append(int(item))
print("Original list (strings):", str_list)
print("Converted list (integers):", int_list)


# 11. Write a program that checks if a number is positive, negative, or zero.

num = float(input("Enter a number: "))

if num > 0:
    print("The number is positive.")
elif num < 0:
    print("The number is negative.")
else:
    print("The number is zero.")


# 12. Write a for loop to print numbers from 1 to 10.

for i in range(1, 11):
    print(i)


# 13. Write a Python program to find the sum of all even numbers between 1 and 50.

i = 1
total = 0

while i <= 50:
    if i % 2 == 0:
        total += i
    i += 1
print(f"Sum of all even numbers between 1 and 50 is: {total}")


# 14. Write a program to reverse a string using a while loop.

string = input('Enter the string: ')
i = string
reverse = ''
while(len(i) > 0):
   if(len(i) > 0):
      a = i[-1]
      i = i[:-1]
      reverse += a
print('The reverse string is', reverse)


# 15. Write a Python program to calculate the factorial of a number provided by the user using a while loop.

num = int(input("Enter a number to find its factorial: "))
fact = 1
i = 1

if num < 0:
    print(" Factorial is not defined for negative numbers.")
else:
    while i <= num:
        fact *= i
        i += 1
    print(f"Factorial of {num} is {fact}")
# Out:
# Hello, World!
